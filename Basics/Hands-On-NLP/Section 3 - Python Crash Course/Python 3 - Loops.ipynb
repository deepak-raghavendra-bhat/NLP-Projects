# %% [markdown]
# Introduction to Python

# %% [markdown]
# Two types of loops in Python

# %% [markdown]
# While Loop

# %% [markdown]
# <br>
# while condition:<br>
#     Statements<br>

# %%
i = 1;

# %%
while i <= 10:
    print(i)
    i += 1
    
# For loop
    
for i in range(1,11):
    print(i)
    
# Nested Loops

# %% [markdown]
# <br>
# 12345<br>
# 12345<br>
# 12345<br>
# 12345<br>

# %%
for i in range(1,5):
    for j in range(1,6):
        print(j,end=" ")
    print()
